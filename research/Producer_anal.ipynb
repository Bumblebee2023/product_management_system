# %% [markdown]
# Резюмируя:
# Завод - поставка - магазин(разные точки)
#
# Всего 1 завод (1 уникальный инн DA6...),
# всеми продуктам и владеет 1 человек (1 уникальный prid, что и сам завод)
# он произвел всего 321 уникальный товар
# есть еще данные о типе ввода в оборот (Рф, из ЭАЕ, возврат и тд)
#
# Перемещаемых товаров 316
# от 1 завода(Da6...)
# 416 уникальных отправителей
# 4500 получателей
# и количества их
#
# Магазины,  4446 групп
# (14886 видов точек откуда возврат)
# ввели 401 уникальный товар в оборот
# и все от 1 поставщика (prid завода DA6... такой же как выше)
# есть цена (5% нули)
# есть колво от 1

# %%
import pandas as pd 
import pandas_profiling 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Импорт данных о производителе

# %%
producer_input = pd.read_csv("Производитель инфа о вводе .csv")
producer_output = pd.read_csv("Производитель инфа о выводе 2 .csv")
producer_move = pd.read_csv("Производитель перемещение .csv")

# %% [markdown]
# #### Анализ данных o вводе в оборот

# %%
producer_input.head(2)
# Out:
#            dt                               inn  \
# 0  2021-11-22  DA62EC79660CF21AC37A260DA6F642C4
# 1  2021-11-22  DA62EC79660CF21AC37A260DA6F642C4
#
#                                gtin                              prid  \
# 0  A279061678C6BCAD8D72041BB2C0A834  DA62EC79660CF21AC37A260DA6F642C4
# 1  3C31611BC8FF7AF82B6E7D8930E11CA8  DA62EC79660CF21AC37A260DA6F642C4
#
#   operation_type  cnt
# 0             РФ  175
# 1             РФ   18

# %%
print(len(producer_input['inn'].unique()))
# Out:
# 1

# %%
producer_input.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.3.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-03-24 18:49:23.871422&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# 1 - производитель и завод
# 1 владелец карточки товаров

# %%
len(producer_input['gtin'].unique())
# Out:
# 321

# %% [markdown]
# ### Анализ данных о выводе из оборота

# %%
producer_output.head(2)
# Out:
#            dt                              gtin  \
# 0  2022-10-15  289AEBCA82877CB19E7AA33E0E522883
# 1  2022-10-15  289AEBCA82877CB19E7AA33E0E522883
#
#                                prid                               inn  \
# 0  DA62EC79660CF21AC37A260DA6F642C4  89F1BFD156A04E3D9B28C7FD6BED4F2F
# 1  DA62EC79660CF21AC37A260DA6F642C4  89F1BFD156A04E3D9B28C7FD6BED4F2F
#
#                              id_sp_  \
# 0  F5DEEE4DB58DAE786ABB7ACC1339E7AC
# 1  0CDC2604FE5051E46DA2A9ED5B318274
#
#                                  type_operation  price  cnt
# 0  Продажа конечному потребителю в точке продаж   1285    2
# 1  Продажа конечному потребителю в точке продаж   1285    2

# %%
print(len(producer_output_2['inn'].unique()))
# Out:
# 4446

# %% [markdown]
# выводили из оборота соответсвенно куча магазинов

# %%
producer_output.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.3.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-03-24 18:49:45.277980&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# 1 владелец карточки

# %%
print(producer_output['inn'].isin(['6B8E111AB5B5C556C0AEA292ACA4D88B']))
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1650152    False
# 1650153    False
# 1650154    False
# 1650155    False
# 1650156    False
# Name: inn, Length: 1650157, dtype: bool

# %% [markdown]
# ### Анализ перемещения товара между участниками

# %%
producer_move.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.3.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-03-24 18:55:08.181579&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# 1 владелец карточки
